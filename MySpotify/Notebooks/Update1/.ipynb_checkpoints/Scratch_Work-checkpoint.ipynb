# %%
# Packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
from datetime import datetime
import scipy.stats as stats
style.use('fivethirtyeight')

# %%
# Checking the encoding of the data
with open("../../Data/PlaylistData/ScanlanShorthalt.csv") as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='../../Data/PlaylistData/ScanlanShorthalt.csv' mode='r' encoding='cp1252'>

# %%
# Importing the data
dfScanlan = pd.read_csv("../../Data/PlaylistData/ScanlanShorthalt.csv", encoding = "cp1252")
dfCatharsis = pd.read_csv("../../Data/PlaylistData/Catharsis.csv", encoding = "cp1252")
dfCarefree = pd.read_csv("../../Data/PlaylistData/Carefree.csv", encoding = "cp1252")
dfSelfLove = pd.read_csv("../../Data/PlaylistData/SelfLove.csv", encoding = "cp1252")
dfThankful = pd.read_csv("../../Data/PlaylistData/Thankful.csv", encoding = "cp1252")
dfLove = pd.read_csv("../../Data/PlaylistData/Love.csv", encoding = "cp1252")
dfNostalgia = pd.read_csv("../../Data/PlaylistData/Nostalgia.csv", encoding = "cp1252")
dfX = pd.read_csv("../../Data/PlaylistData/X.csv", encoding = "cp1252")
playlists = [ dfCatharsis, dfSelfLove, dfLove, dfNostalgia, dfX] # dfScanlan, dfThankful, dfCarefree, 
playlistName = ["Catharsis", "Self Love", "Love", "Nostalgia", "X"] # "Scanlan Shorthalt", "Thankful", "Carefree",

# %%
# Changing "Length" to a float in each dataset
i = 0
for playlist in playlists:
#     print(playlistName[i])
    playlist["Length"] = playlist.apply(lambda row: datetime.strptime(row["Length"], '%M:%S'), axis = 1)
    playlist["Length"] = (playlist["Length"].dt.minute * 60 + playlist["Length"].dt.second)
    i += 1

# %%
# Merging into one Dataset
df = pd.DataFrame(columns = dfScanlan.columns)

i = 0
for playlist in playlists:
    playlist["Playlist"] = playlistName[i]
    df = df.append(playlist)
    i += 1

# Changes relevant attributes to floats
attributes = ["BPM", "Energy", "Dance", "Loud", "Valence", "Length", "Acoustic", "Popularity"]
for atr in attributes:
    df[atr] = df[atr].astype(float)
    
df.head()
# Out:
#                  Song    Artist    Release    BPM  Energy  Dance  Loud  \
# 0      Blood // Water  grandson  6/15/2018  154.0    89.0   50.0  -6.0
# 1  thoughts & prayers  grandson  3/23/2018  150.0    93.0   49.0  -3.0
# 2            Stick Up  grandson  6/15/2018  136.0    93.0   31.0  -5.0
# 3            Overdose  grandson  6/15/2018  144.0    69.0   53.0  -6.0
# 4                6:00  grandson  6/15/2018   96.0    81.0   29.0  -6.0
#
#    Valence  Length  Acoustic  Popularity   Rnd   Playlist
# 0     63.0   215.0       0.0        72.0  1736  Catharsis
# 1     33.0   225.0       0.0        61.0  4109  Catharsis
# 2     30.0   223.0       0.0        61.0  9971  Catharsis
# 3     12.0   231.0       0.0        59.0   111  Catharsis
# 4     35.0   266.0       0.0        58.0  7924  Catharsis

# %% [markdown]
# # BPM

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["BPM"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "BPM", data = df)

# %% [markdown]
# # Energy

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Energy"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Energy", data = df)

# %% [markdown]
# # Dance

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Dance"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Dance", data = df)

# %% [markdown]
# # Loud

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Loud"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Loud", data = df)

# %% [markdown]
# # Valence

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Valence"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Valence", data = df)

# %% [markdown]
# # Length

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Length"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "BPM", data = df)

# %% [markdown]
# # Acoustic

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Acoustic"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Acoustic", data = df)

# %% [markdown]
# # Popularity

# %%
plt.figure(figsize = (15,5))

i = 0
for playlist in playlists:
    sns.kdeplot(playlist["Popularity"], label = playlistName[i])
    i += 1

plt.legend(loc = "upper right")

# %%
plt.figure(figsize = (15,5))

sns.boxplot(x = "Playlist", y = "Popularity", data = df)
